# %% [markdown]
# # Titulo
#
# ## subtitulo
#
# Teoría del zeeman
# Hablada
#
#
# $mate dentro de dolar$
#
# $$mate en el centro dentro de dolar$$
#
# ejemoplo de ecuacion
#
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $
#
# **negrita**
#
# *italics*

# %%
# %run ./zeemaneffect.ipynb

# %%
graphforN(2)
graphforN(3)
graphforN(4)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
